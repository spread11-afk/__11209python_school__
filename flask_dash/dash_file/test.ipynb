# %%
import datasource
import pandas as pd
lastest_data=datasource.lastest_datetime_data()
lastest_df=pd.DataFrame(lastest_data,columns=['站點名稱','更新時間','行政區','地址','總數','可借','可還',])
lastest_df
# Out:
#                              0                    1       2              3  \
# 0            YouBike2.0_市民敦化路口  2023-11-29 14:52:15     大安區    敦化南路一段111號前
# 1           YouBike2.0_捷運科技大樓站  2023-11-29 14:52:05     大安區    復興南路二段235號前
# 2       YouBike2.0_復興南路二段273號前  2023-11-29 14:52:05     大安區   復興南路二段273號西側
# 3         YouBike2.0_國北教大實小東側門  2023-11-29 14:52:05     大安區    和平東路二段96巷7號
# 4            YouBike2.0_和平公園東側  2023-11-29 14:52:05     大安區  和平東路二段118巷33號
# ...                        ...                  ...     ...            ...
# 1318      YouBike2.0_臺大總圖書館西南側  2023-11-29 14:52:15  臺大公館校區       臺大圖書館西南側
# 1319        YouBike2.0_臺大黑森林西側  2023-11-29 14:52:15  臺大公館校區        臺大霖澤館南側
# 1320        YouBike2.0_臺大獸醫館南側  2023-11-29 14:52:15  臺大公館校區       臺大獸醫系館南側
# 1321      YouBike2.0_臺大新體育館東南側  2023-11-29 14:52:15  臺大公館校區        臺大體育館東側
# 1322  YouBike2.0_臺大明達館北側(員工宿舍)  2023-11-29 14:52:15  臺大公館校區       明達館北側前空地
#
#        4   5   6
# 0     15   7   8
# 1     28   1  27
# 2     21   1  20
# 3     16   6  10
# 4     11   0  11
# ...   ..  ..  ..
# 1318  30  29   1
# 1319  20   2  18
# 1320  24  10  11
# 1321  40  13  22
# 1322  18   0  18
#
# [1323 rows x 7 columns]
